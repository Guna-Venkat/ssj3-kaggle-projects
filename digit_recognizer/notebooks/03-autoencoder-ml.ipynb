# %% [markdown]
# ## 🎯 Goal:
# - Use an autoencoder to compress image features, then use those compressed vectors as input to SVC, RF, or other ML models.

# %%
import pandas as pd

train_df = pd.read_csv("/kaggle/input/digit-recognizer/train.csv")
X = train_df.drop('label', axis=1) / 255.0
y = train_df['label']

# zero mask
zero_mask = (X == 0).sum(axis=0) / len(X) > 0.95

# Apply zero_mask to remove sparse pixels
X = X.loc[:, ~zero_mask]

# %%
from sklearn.model_selection import train_test_split

# split the data
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import regularizers

input_dim = X_train.shape[1]
encoding_dim = 64  # or 32, you can tune this

input_img = Input(shape=(input_dim,))
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(encoding_dim, activation='relu')(encoded)

decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 398)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          51,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 398)                 │          51,342 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 118,990 (464.80 KB)
#  Trainable params: 118,990 (464.80 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.fit(X_train, X_train,
                epochs=100,
                batch_size=512,
                shuffle=True,
                validation_data=(X_val, X_val))
# Out:
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1577 - val_loss: 0.0772
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0680 - val_loss: 0.0475
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0440 - val_loss: 0.0352
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0336 - val_loss: 0.0292
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0284 - val_loss: 0.0262
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0255 - val_loss: 0.0237
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0232 - val_loss: 0.0223
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0216 - val_loss: 0.0206
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0203 - val_loss: 0.0195
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0192 - val_loss: 0.0186
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0183 - val_loss: 0.0178
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0168 - val_loss: 0.0166
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0164 - val_loss: 0.0160
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0157 - val_loss: 0.0155
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0155 - val_loss: 0.0150
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0149 - val_loss: 0.0147
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0144
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0143 - val_loss: 0.0140
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0139 - val_loss: 0.0137
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0135 - val_loss: 0.0134
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0132 - val_loss: 0.0132
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0130 - val_loss: 0.0128
# Epoch 25/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0127 - val_loss: 0.0126
# Epoch 26/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0125 - val_loss: 0.0124
# Epoch 27/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0122 - val_loss: 0.0123
# Epoch 28/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0121 - val_loss: 0.0122
# Epoch 29/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0119 - val_loss: 0.0119
# Epoch 30/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0118 - val_loss: 0.0119
# Epoch 31/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0116 - val_loss: 0.0116
# Epoch 32/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0115 - val_loss: 0.0114
# Epoch 33/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0112 - val_loss: 0.0113
# Epoch 34/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0112 - val_loss: 0.0112
# Epoch 35/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 36/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 37/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0109 - val_loss: 0.0108
# Epoch 38/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 39/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 40/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0106 - val_loss: 0.0106
# Epoch 41/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0105 - val_loss: 0.0105
# Epoch 42/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0104 - val_loss: 0.0104
# Epoch 43/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 44/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0103 - val_loss: 0.0104
# Epoch 45/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0101 - val_loss: 0.0103
# Epoch 46/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0101 - val_loss: 0.0102
# Epoch 47/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0100 - val_loss: 0.0101
# Epoch 48/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 49/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 50/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 51/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0098 - val_loss: 0.0097
# Epoch 52/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 53/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0096 - val_loss: 0.0096
# Epoch 54/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 55/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0094 - val_loss: 0.0096
# Epoch 56/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0094 - val_loss: 0.0095
# Epoch 57/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 58/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 59/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 60/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0091 - val_loss: 0.0092
# Epoch 61/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 62/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 63/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 64/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 65/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 66/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 67/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 68/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 69/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 70/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 71/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 72/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 73/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 74/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 75/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 76/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 77/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 78/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 79/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0083 - val_loss: 0.0084
# Epoch 80/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0083 - val_loss: 0.0083
# Epoch 81/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 82/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 83/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 84/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 85/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - val_loss: 0.0083
# Epoch 86/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 87/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 88/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 89/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 90/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 91/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 92/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 93/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0081
# Epoch 94/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 95/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0079 - val_loss: 0.0081
# Epoch 96/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 97/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 98/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 99/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0080
# Epoch 100/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0078 - val_loss: 0.0080

# %%
X_train_enc = encoder.predict(X_train)
X_val_enc = encoder.predict(X_val)
# Out:
# 1182/1182 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

svc = SVC(C=10, kernel='rbf', gamma='scale', probability=True)
svc.fit(X_train_enc, y_train)
y_pred = svc.predict(X_val_enc)

print("📊 Accuracy:", accuracy_score(y_val, y_pred))
print("📄 Report:\n", classification_report(y_val, y_pred))
# Out:
# 📊 Accuracy: 0.9754761904761905
# 📄 Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       413
#            1       0.99      0.99      0.99       468
#            2       0.97      0.98      0.97       418
#            3       0.97      0.96      0.97       435
#            4       0.99      0.99      0.99       407
#            5       0.95      0.97      0.96       380
#            6       0.98      0.99      0.98       414
#            7       0.98      0.98      0.98       440
#            8       0.97      0.95      0.96       406
#            9       0.96      0.96      0.96       419
#
#     accuracy                           0.98      4200
#    macro avg       0.98      0.98      0.98      4200
# weighted avg       0.98      0.98      0.98      4200

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

rf = RandomForestClassifier(n_estimators=200, max_depth=20, random_state=42)
rf.fit(X_train_enc, y_train)

y_pred_rf = rf.predict(X_val_enc)
print("🌳 RF Accuracy:", accuracy_score(y_val, y_pred_rf))
print(classification_report(y_val, y_pred_rf))
# Out:
# 🌳 RF Accuracy: 0.9276190476190476
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       413
#            1       0.99      0.99      0.99       468
#            2       0.93      0.93      0.93       418
#            3       0.87      0.89      0.88       435
#            4       0.94      0.93      0.93       407
#            5       0.89      0.88      0.89       380
#            6       0.92      0.97      0.94       414
#            7       0.93      0.95      0.94       440
#            8       0.92      0.85      0.89       406
#            9       0.91      0.92      0.92       419
#
#     accuracy                           0.93      4200
#    macro avg       0.93      0.93      0.93      4200
# weighted avg       0.93      0.93      0.93      4200

# %%
from catboost import CatBoostClassifier

cat = CatBoostClassifier(
    iterations=300,
    learning_rate=0.1,
    depth=6,
    verbose=0,
    random_state=42
)
cat.fit(X_train_enc, y_train)

y_pred_cat = cat.predict(X_val_enc)
print("🐱 CatBoost Accuracy:", accuracy_score(y_val, y_pred_cat))
print(classification_report(y_val, y_pred_cat))
# Out:
# 🐱 CatBoost Accuracy: 0.9269047619047619
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       413
#            1       0.97      0.98      0.98       468
#            2       0.93      0.92      0.92       418
#            3       0.91      0.91      0.91       435
#            4       0.95      0.93      0.94       407
#            5       0.88      0.91      0.89       380
#            6       0.93      0.97      0.95       414
#            7       0.93      0.93      0.93       440
#            8       0.92      0.85      0.88       406
#            9       0.89      0.91      0.90       419
#
#     accuracy                           0.93      4200
#    macro avg       0.93      0.93      0.93      4200
# weighted avg       0.93      0.93      0.93      4200

# %%
from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(
    estimators=[
        ('svc',svc),
        ('rf', rf),
        ('cat', cat)
    ],
    voting='soft'  # use predicted probabilities
)
voting_clf.fit(X_train_enc, y_train)

y_pred_vote = voting_clf.predict(X_val_enc)
print("🗳️ Voting Accuracy:", accuracy_score(y_val, y_pred_vote))
print(classification_report(y_val, y_pred_vote))
# Out:
# 🗳️ Voting Accuracy: 0.9726190476190476
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       413
#            1       0.99      1.00      0.99       468
#            2       0.97      0.97      0.97       418
#            3       0.97      0.95      0.96       435
#            4       0.99      0.99      0.99       407
#            5       0.95      0.96      0.95       380
#            6       0.97      0.99      0.98       414
#            7       0.98      0.98      0.98       440
#            8       0.97      0.95      0.96       406
#            9       0.96      0.96      0.96       419
#
#     accuracy                           0.97      4200
#    macro avg       0.97      0.97      0.97      4200
# weighted avg       0.97      0.97      0.97      4200

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->xgboost) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->xgboost) (2024.2.0)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

mlp = MLPClassifier(hidden_layer_sizes=(128, 64),
                    activation='relu',
                    solver='adam',
                    learning_rate='adaptive',
                    alpha=1e-3,
                    max_iter=300,
                    random_state=42)

mlp.fit(X_train_enc, y_train)

y_pred_mlp = mlp.predict(X_val_enc)
acc = accuracy_score(y_val, y_pred_mlp)

print("🧠 MLPClassifier Accuracy:", acc)
print("📄 Classification Report:")
print(classification_report(y_val, y_pred_mlp))
# Out:
# 🧠 MLPClassifier Accuracy: 0.9704761904761905
# 📄 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       413
#            1       0.99      0.99      0.99       468
#            2       0.97      0.97      0.97       418
#            3       0.98      0.95      0.97       435
#            4       0.96      1.00      0.98       407
#            5       0.94      0.96      0.95       380
#            6       0.95      1.00      0.97       414
#            7       0.98      0.97      0.98       440
#            8       0.98      0.94      0.96       406
#            9       0.96      0.95      0.95       419
#
#     accuracy                           0.97      4200
#    macro avg       0.97      0.97      0.97      4200
# weighted avg       0.97      0.97      0.97      4200

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'hidden_layer_sizes': [(64,), (128,), (128, 64), (256, 128)],
    'activation': ['relu', 'tanh'],
    'alpha': [1e-4, 1e-3, 1e-2],
    'learning_rate': ['constant', 'adaptive']
}

mlp_base = MLPClassifier(max_iter=300, random_state=42)

search = RandomizedSearchCV(mlp_base, param_dist, n_iter=5, cv=3,
                            scoring='accuracy', verbose=2, n_jobs=-1)
search.fit(X_train_enc, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# RandomizedSearchCV(cv=3, estimator=MLPClassifier(max_iter=300, random_state=42),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'activation': ['relu', 'tanh'],
#                                         'alpha': [0.0001, 0.001, 0.01],
#                                         'hidden_layer_sizes': [(64,), (128,),
#                                                                (128, 64),
#                                                                (256, 128)],
#                                         'learning_rate': ['constant',
#                                                           'adaptive']},
#                    scoring='accuracy', verbose=2)
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 2.0min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 3.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(128,), learning_rate=adaptive; total time= 3.4min
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=adaptive; total time=  58.7s
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 2.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(128,), learning_rate=adaptive; total time= 4.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 1.8min
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=adaptive; total time= 1.1min
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 1.7min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 4.6min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 2.1min
# [CV] END activation=relu, alpha=0.0001, hidden_layer_sizes=(64,), learning_rate=adaptive; total time= 1.1min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 4.4min
# [CV] END activation=relu, alpha=0.01, hidden_layer_sizes=(128,), learning_rate=adaptive; total time= 2.4min
# [CV] END activation=relu, alpha=0.001, hidden_layer_sizes=(256, 128), learning_rate=adaptive; total time= 1.8min

# %%
search.best_params_
# Out:
# {'learning_rate': 'adaptive',
#  'hidden_layer_sizes': (256, 128),
#  'alpha': 0.0001,
#  'activation': 'relu'}

# %%
print(f"✅ Best CV Accuracy: {search.best_score_:.4f}")
# Out:
# ✅ Best CV Accuracy: 0.9733
